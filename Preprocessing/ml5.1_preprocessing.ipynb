# %% [markdown]
# ## Лабораторная работа № 12. Предварительная обработка данных.
# ### (Валяев Георгий, ПИ20-6)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import seaborn as sns
import traceback

# %% [markdown]
# ### Задания для выполнения

# %% [markdown]
# ##### 1. Загрузите и прочитайте в pandas приложенный датасет. Обратите внимание, что датасет собран «криво», поэтому прежде чем он «правильно» загрузится (рис.1), необходимо его обработать.

# %%
dataframe = pd.read_csv('data/cars_sampled.csv', parse_dates=["dateCreated", "lastSeen", "dateCrawled"])
dataframe
# Out:
#               dateCrawled                                               name  \
# 0     2016-03-30 13:51:00                                       Zu_verkaufen
# 1     2016-07-03 09:54:00                             Volvo_XC90_2.4D_Summum
# 2     2016-01-04 00:57:00                                  Volkswagen_Touran
# 3     2016-03-19 17:50:00                       Seat_Ibiza_1.4_16V_Reference
# 4     2016-03-16 14:51:00  Volvo_XC90_D5_Aut._RDesign_R_Design_AWD_GSHD_S...
# ...                   ...                                                ...
# 49996 2016-03-04 15:48:00                               Suche_VW_T5_Multivan
# 49997 2016-03-27 14:55:00  Suche_einen_originalen_VW_Golf_2_Fire_and_Ice_G60
# 49998 2016-03-14 18:51:00  [SUCHE]_BMW_e46_Coupe_330ci_M_Paket_Facelift__...
# 49999 2016-03-15 18:06:00        Verkaufe_mehrere_Fahrzeuge_zum_Verschrotten
# 50000 2016-03-22 09:54:00                    Chevrolet_Matiz_1.Hd_TÜV11/2017
#
#            seller offerType  price   abtest    vehicleType  \
# 0         private     offer   4450     test      limousine
# 1         private     offer  13299  control            suv
# 2         private     offer   3200     test            bus
# 3         private     offer   4500  control      small car
# 4         private     offer  18750     test            suv
# ...           ...       ...    ...      ...            ...
# 49996     private   request      0     test            bus
# 49997     private   request  19999  control            NaN
# 49998     private   request      0     test          coupe
# 49999  commercial     offer    100  control  station wagon
# 50000  commercial     offer   1100     test      small car
#
#        yearOfRegistration    gearbox  powerPS        model  kilometer  \
# 0                    2003     manual      150          3er     150000
# 1                    2005     manual      163     xc_reihe     150000
# 2                    2003     manual      101       touran     150000
# 3                    2006     manual       86        ibiza      60000
# 4                    2008  automatic      185     xc_reihe     150000
# ...                   ...        ...      ...          ...        ...
# 49996                2005        NaN        0  transporter     150000
# 49997                1990        NaN        0         golf       5000
# 49998                2004     manual        0          3er     150000
# 49999                2000     manual        0       megane     150000
# 50000                2006     manual       38        matiz     150000
#
#        monthOfRegistration fuelType       brand notRepairedDamage dateCreated  \
# 0                        3   diesel         bmw               NaN  2016-03-30
# 1                        6   diesel       volvo                no  2016-07-03
# 2                       11   diesel  volkswagen               NaN  2016-03-31
# 3                       12   petrol        seat                no  2016-03-19
# 4                       11   diesel       volvo                no  2016-03-16
# ...                    ...      ...         ...               ...         ...
# 49996                    0      NaN  volkswagen               NaN  2016-03-04
# 49997                    0      NaN  volkswagen               NaN  2016-03-27
# 49998                    1   petrol         bmw                no  2016-03-14
# 49999                    8   petrol     renault               NaN  2016-03-15
# 50000                   10   petrol   chevrolet                no  2016-03-22
#
#        postalCode            lastSeen
# 0           20257 2016-07-04 04:44:00
# 1           88045 2016-03-26 13:17:00
# 2           27449 2016-01-04 08:40:00
# 3           34537 2016-07-04 04:44:00
# 4           55270 2016-01-04 23:18:00
# ...           ...                 ...
# 49996       29690 2016-05-04 15:16:00
# 49997       50181 2016-07-04 11:45:00
# 49998       86956 2016-03-25 06:17:00
# 49999       65232 2016-06-04 17:15:00
# 50000        7973 2016-05-04 21:15:00
#
# [50001 rows x 19 columns]

# %% [markdown]
# ##### 2. Сделайте описательную статистику: размер, типы переменных, пустые значения, уникальные имена и т.д.

# %%
print("Размерность: ", dataframe.shape)
print("Имена столбцов данных: ", dataframe.columns)
# Out:
# Размерность:  (50001, 19)
# Имена столбцов данных:  Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'postalCode', 'lastSeen'],
#       dtype='object')

# %%
print("Типы переменных:\n", dataframe.dtypes, sep='')
# Out:
# Типы переменных:
# dateCrawled            datetime64[ns]
# name                           object
# seller                         object
# offerType                      object
# price                           int64
# abtest                         object
# vehicleType                    object
# yearOfRegistration              int64
# gearbox                        object
# powerPS                         int64
# model                          object
# kilometer                       int64
# monthOfRegistration             int64
# fuelType                       object
# brand                          object
# notRepairedDamage              object
# dateCreated            datetime64[ns]
# postalCode                      int64
# lastSeen               datetime64[ns]
# dtype: object

# %%
# краткая информация о составе и описание датасета
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50001 entries, 0 to 50000
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          50001 non-null  datetime64[ns]
#  1   name                 50001 non-null  object
#  2   seller               50001 non-null  object
#  3   offerType            50001 non-null  object
#  4   price                50001 non-null  int64
#  5   abtest               50001 non-null  object
#  6   vehicleType          44813 non-null  object
#  7   yearOfRegistration   50001 non-null  int64
#  8   gearbox              47177 non-null  object
#  9   powerPS              50001 non-null  int64
#  10  model                47243 non-null  object
#  11  kilometer            50001 non-null  int64
#  12  monthOfRegistration  50001 non-null  int64
#  13  fuelType             45498 non-null  object
#  14  brand                50001 non-null  object
#  15  notRepairedDamage    40285 non-null  object
#  16  dateCreated          50001 non-null  datetime64[ns]
#  17  postalCode           50001 non-null  int64
#  18  lastSeen             50001 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), int64(6), object(10)
# memory usage: 7.2+ MB

# %%
# краткая справка по описательной статистике датасета
dataframe.describe()
# Out:
#               price  yearOfRegistration       powerPS      kilometer  \
# count  5.000100e+04        50001.000000  50001.000000   50001.000000
# mean   6.559865e+03         2005.544229    116.496130  125613.687726
# std    8.581847e+04          122.991832    230.567709   40205.234483
# min    0.000000e+00         1000.000000      0.000000    5000.000000
# 25%    1.150000e+03         1999.000000     69.000000  125000.000000
# 50%    2.950000e+03         2003.000000    105.000000  150000.000000
# 75%    7.190000e+03         2008.000000    150.000000  150000.000000
# max    1.234568e+07         9999.000000  19312.000000  150000.000000
#
#        monthOfRegistration    postalCode
# count         50001.000000  50001.000000
# mean              5.743725  50775.216696
# std               3.711345  25743.701933
# min               0.000000   1067.000000
# 25%               3.000000  30559.000000
# 50%               6.000000  49504.000000
# 75%               9.000000  71404.000000
# max              12.000000  99998.000000

# %%
# количество пустых значений у полей датасета
dataframe.isna().sum()
# Out:
# dateCrawled               0
# name                      0
# seller                    0
# offerType                 0
# price                     0
# abtest                    0
# vehicleType            5188
# yearOfRegistration        0
# gearbox                2824
# powerPS                   0
# model                  2758
# kilometer                 0
# monthOfRegistration       0
# fuelType               4503
# brand                     0
# notRepairedDamage      9716
# dateCreated               0
# postalCode                0
# lastSeen                  0
# dtype: int64

# %%
print("Уникальные имена в полях данных датасета:")
data_scale = pd.concat([dataframe.dtypes, dataframe.apply(lambda item: item.unique())], axis=1)
data_scale.columns = ['Type_data', 'Unique_values']
data_scale
# Out:
# Уникальные имена в полях данных датасета:
#                           Type_data  \
# dateCrawled          datetime64[ns]
# name                         object
# seller                       object
# offerType                    object
# price                         int64
# abtest                       object
# vehicleType                  object
# yearOfRegistration            int64
# gearbox                      object
# powerPS                       int64
# model                        object
# kilometer                     int64
# monthOfRegistration           int64
# fuelType                     object
# brand                        object
# notRepairedDamage            object
# dateCreated          datetime64[ns]
# postalCode                    int64
# lastSeen             datetime64[ns]
#
#                                                          Unique_values
# dateCrawled          [2016-03-30T13:51:00.000000000, 2016-07-03T09:...
# name                 [Zu_verkaufen, Volvo_XC90_2.4D_Summum, Volkswa...
# seller                                           [private, commercial]
# offerType                                             [offer, request]
# price                [4450, 13299, 3200, 4500, 18750, 988, 400, 139...
# abtest                                                 [test, control]
# vehicleType          [limousine, suv, bus, small car, station wagon...
# yearOfRegistration   [2003, 2005, 2006, 2008, 1995, 1996, 1997, 200...
# gearbox                                       [manual, automatic, nan]
# powerPS              [150, 163, 101, 86, 185, 90, 0, 136, 122, 140,...
# model                [3er, xc_reihe, touran, ibiza, passat, astra, ...
# kilometer            [150000, 60000, 125000, 5000, 50000, 80000, 90...
# monthOfRegistration         [3, 6, 11, 12, 2, 5, 4, 1, 9, 0, 10, 8, 7]
# fuelType             [diesel, petrol, nan, cng, lpg, hybrid, electr...
# brand                [bmw, volvo, volkswagen, seat, opel, mercedes_...
# notRepairedDamage                                       [nan, no, yes]
# dateCreated          [2016-03-30T00:00:00.000000000, 2016-07-03T00:...
# postalCode           [20257, 88045, 27449, 34537, 55270, 26826, 564...
# lastSeen             [2016-07-04T04:44:00.000000000, 2016-03-26T13:...

# %% [markdown]
# ##### 3. Поработайте с типами переменных. Все числовые значения переведите в формат int.

# %% [markdown]
# ###### Исходя из описания типов переменных полей датасета, можно смело говорить о том, что все значения имеют целочисленный тип!

# %% [markdown]
# ##### 4. Поработайте со столбцом price. Постройте гистограмму, найдите выбросы (ящиковая диаграмма), удалите аномальные значения, постарайтесь привести к нормальному распределению.

# %%
print("Гистограмма по столбцу price")
dataframe.hist(column="price", legend=True)
# Out:
# Гистограмма по столбцу price
# array([[<AxesSubplot: title={'center': 'price'}>]], dtype=object)

# %%
print("Ящик с усами до удаления выбросов")
dataframe['price'].plot.box(flierprops={"marker": "x"})
# Out:
# Ящик с усами до удаления выбросов
# <AxesSubplot: >

# %%
print("Проверка price на наличие значений NaN и null")
dataframe['price'].isna().sum()
# Out:
# Проверка price на наличие значений NaN и null
# 0

# %%
print("Чистка выбросов")
for x_elem in tqdm(['price']):
    q75, q25 = np.percentile(dataframe.loc[:, x_elem], [75, 25])
    iqr = q75 - q25

    dataframe.loc[dataframe[x_elem] > q75 + 1.5*iqr, x_elem] = np.nan
    dataframe.loc[dataframe[x_elem] < q25 - 1.5*iqr, x_elem] = np.nan

dataframe['price'].plot.box(flierprops={"marker": "x"})
# Out:
# Чистка выбросов
#   0%|          | 0/1 [00:00<?, ?it/s]
# <AxesSubplot: >

# %%
print("Гистограмма price после очистки выбросов")
dataframe.hist(column='price', legend=True)
# Out:
# Гистограмма price после очистки выбросов
# array([[<AxesSubplot: title={'center': 'price'}>]], dtype=object)

# %%
print("Нормализируем данные через логарифм")
dataframe['price'] = np.log(dataframe['price'] + 1)
dataframe.hist(column='price', legend=True)
# Out:
# Нормализируем данные через логарифм
# array([[<AxesSubplot: title={'center': 'price'}>]], dtype=object)

# %%
print("В результате нормализации данных появились значения NaN и null, что вполне логично ==> ", dataframe['price'].isna().sum(), " элементов", sep='')
# Out:
# В результате нормализации данных появились значения NaN и null, что вполне логично ==> 3757 элементов

# %% [markdown]
# ##### 5. Аналогично поработайте и с другими «важными для целевой функции price» параметрами (powerPS, yearOfRegistration, kilometer и т.д). «Важность» докажите через коэффициент корреляции. Сделайте визуализацию.

# %%
print("Первым делом построим корреляционную матрицу")
dataframe.corr()
# Out:
# Первым делом построем корреляционную матрицу
#                         price  yearOfRegistration   powerPS  kilometer  \
# price                1.000000            0.005603  0.096838  -0.108628
# yearOfRegistration   0.005603            1.000000 -0.004394  -0.064188
# powerPS              0.096838           -0.004394  1.000000  -0.016447
# kilometer           -0.108628           -0.064188 -0.016447   1.000000
# monthOfRegistration  0.170537           -0.023152  0.034345   0.001985
# postalCode           0.068389           -0.001615  0.017415  -0.024076
#
#                      monthOfRegistration  postalCode
# price                           0.170537    0.068389
# yearOfRegistration             -0.023152   -0.001615
# powerPS                         0.034345    0.017415
# kilometer                       0.001985   -0.024076
# monthOfRegistration             1.000000    0.019050
# postalCode                      0.019050    1.000000

# %%
print("Визуализируем эту матрицу через тепловую карту seaborn")
sns.heatmap(dataframe.corr(), vmin=-1, vmax=1, center=0, square=True, annot=True).figure.set_size_inches(11, 11)
# Out:
# Визуализируем эту матрицу через тепловую карту seaborn

# %% [markdown]
# ###### Проанализировав тепловую карту, можно сказать об очень слабой и холодной отчасти связи факторов и целевой переменной price

# %% [markdown]
# ##### 6. Постройте ящиковые диаграммы зависимости gearbox, fuelType, vehicleType, notRepairedDamage от price. Сделайте выводы. Можно ли убрать значения с малой частотой? Повлияет ли это на дальнейшее исследование?

# %%
sns.set(rc={"figure.figsize":(14, 7)})
print("Ящик с усами между столбцами price и gearbox")
sns.boxplot(data=dataframe, y='price', x='gearbox', hue='gearbox', flierprops={"marker": "x"})
# Out:
# Ящик с усами между столбцами price и gearbox
# <AxesSubplot: xlabel='gearbox', ylabel='price'>

# %% [markdown]
# ###### По распределению цен в этом признаке видно, что вариант автоматической коробки передач выглядит дороже механики

# %%
sns.set(rc={"figure.figsize":(16, 7)})
print("Ящик с усами между столбцами price и fuelType")
sns.boxplot(data=dataframe, y='price', x='fuelType', hue='fuelType', flierprops={"marker": "x"})
# Out:
# Ящик с усами между столбцами price и fuelType
# <AxesSubplot: xlabel='fuelType', ylabel='price'>

# %% [markdown]
# ###### Гибридные модели здесь наиболее дорогие, а электрические — самые короткие по ценовому диапазону

# %%
sns.set(rc={"figure.figsize":(16, 7)})
print("Ящик с усами между столбцами price и vehicleType")
sns.boxplot(data=dataframe, y='price', x='vehicleType', hue='vehicleType', flierprops={"marker": "x"})
# Out:
# Ящик с усами между столбцами price и vehicleType
# <AxesSubplot: xlabel='vehicleType', ylabel='price'>

# %% [markdown]
# ###### На этом графике ящиков с усами видно, что внедорожники выглядят дороже всех

# %%
sns.set(rc={"figure.figsize":(14, 7)})
print("Ящик с усами между столбцами price и notRepairedDamage")
sns.boxplot(data=dataframe, y='price', x='notRepairedDamage', hue='notRepairedDamage', flierprops={"marker": "x"})
# Out:
# Ящик с усами между столбцами price и notRepairedDamage
# <AxesSubplot: xlabel='notRepairedDamage', ylabel='price'>

# %% [markdown]
# ###### Из этого графика следует довольно логичный график, что те автомобили, которые невозможно починить, стоят дешевле других

# %% [markdown]
# ###### Легко увидеть в каждом графике обильное количество выбросов данных, но этот фактор не играет большой роли при последующем анализе ящиков с усами факторов вразрез со столбцом цены в датасете.
# ###### Так что, отвечая на вопрос о возможном удалении значений с малой частотой, можно сказать, что нет, не обязательно, поскольку это не сильно повлияет на дальнейшее исследование (результаты будут +- аналогичные).

# %% [markdown]
# ##### 7. Найдите пропуски. Удалите столбцы, которые содержат большое количество пропусков. В остальных случаях постарайтесь восстановить пропущенные значения.

# %%
dataframe.isna().sum()[dataframe.isna().sum() > 0]
# Out:
# price                3757
# vehicleType          5188
# gearbox              2824
# model                2758
# fuelType             4503
# notRepairedDamage    9716
# dtype: int64

# %% [markdown]
# ###### Так как в столбце данных notRepairedDamage обильное количество пустых значений, сначала удалим его

# %%
dataframe = dataframe.dropna(subset=["notRepairedDamage"])
try:
    assert dataframe["notRepairedDamage"].isna().sum() == 0
    print("Проверка прошла успешно, пустые значения столбца notRepairedDamage удалены!")
except:
    print("В процессе проверки случилась следующая ошибка:")
    print(traceback.format_exc())
# Out:
# Проверка прошла успешно, пустые значения столбца notRepairedDamage удалены!

# %% [markdown]
# ###### Исследуем оставшиеся пустые значения полей данных нашего датасета. Поскольку они — категориальные, то мы сможем закрыть нынешнюю проблему с пустыми значениями через их прямое удаление или замену на медианный элемент

# %%
dataframe.isna().sum()[dataframe.isna().sum() > 0].to_dict().keys()

# %%
for column in tqdm(dataframe.isna().sum()[dataframe.isna().sum() > 0].to_dict().keys()):
    sns.countplot(x=dataframe[column])
    plt.show()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
# Для признаков, кроме model и price, выставляем моду
for column in ["fuelType", "gearbox", "vehicleType"]:
    dataframe[column] = dataframe[column].fillna(dataframe[column].value_counts().index[0])

dataframe.isna().sum()[dataframe.isna().sum() > 0]
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_12296/1246985231.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[column] = dataframe[column].fillna(dataframe[column].value_counts().index[0])
# price    3548
# model    1519
# dtype: int64

# %%
# признаки price и model удаляем из выборки
dataframe = dataframe.dropna()
dataframe.shape
# Out:
# (35348, 19)

# %% [markdown]
# ##### 8. Сохраните полученный датасет и выведите его.

# %%
dataframe
# Out:
#               dateCrawled                                               name  \
# 1     2016-07-03 09:54:00                             Volvo_XC90_2.4D_Summum
# 3     2016-03-19 17:50:00                       Seat_Ibiza_1.4_16V_Reference
# 5     2016-02-04 12:51:00           VW_Passat_35i_Facelift_Limousine_TÜV_Neu
# 7     2016-03-24 15:52:00                        Mercedes_Benz_CLK_Coupe_200
# 8     2016-03-28 14:40:00  Vectra_C_Caravan_1_8_Edition_Facelift_m_AHK_In...
# ...                   ...                                                ...
# 49992 2016-03-14 13:57:00                         Opel_Astra_2.0_DI_Elegance
# 49993 2016-03-14 11:37:00       Renault_Clio_mit_Servolenkung_und_neuem_TÜV!
# 49995 2016-03-23 21:45:00  Opel_Astra_G_Caravan__Tuev_2/2018__Scheckheft_...
# 49998 2016-03-14 18:51:00  [SUCHE]_BMW_e46_Coupe_330ci_M_Paket_Facelift__...
# 50000 2016-03-22 09:54:00                    Chevrolet_Matiz_1.Hd_TÜV11/2017
#
#            seller offerType     price   abtest    vehicleType  \
# 1         private     offer  9.495519  control            suv
# 3         private     offer  8.412055  control      small car
# 5         private     offer  6.896694     test      limousine
# 7         private     offer  7.244228     test          coupe
# 8         private     offer  8.451267     test  station wagon
# ...           ...       ...       ...      ...            ...
# 49992     private     offer  6.673298     test      limousine
# 49993     private     offer  6.722630     test      small car
# 49995     private     offer  7.736744     test  station wagon
# 49998     private   request  0.000000     test          coupe
# 50000  commercial     offer  7.003974     test      small car
#
#        yearOfRegistration gearbox  powerPS     model  kilometer  \
# 1                    2005  manual      163  xc_reihe     150000
# 3                    2006  manual       86     ibiza      60000
# 5                    1995  manual       90    passat     150000
# 7                    1997  manual      136       clk     150000
# 8                    2005  manual      122    vectra     150000
# ...                   ...     ...      ...       ...        ...
# 49992                1998  manual       82     astra     150000
# 49993                1999  manual       60      clio     125000
# 49995                2001  manual      101     astra     150000
# 49998                2004  manual        0       3er     150000
# 50000                2006  manual       38     matiz     150000
#
#        monthOfRegistration fuelType          brand notRepairedDamage  \
# 1                        6   diesel          volvo                no
# 3                       12   petrol           seat                no
# 5                        2   petrol     volkswagen                no
# 7                       11   petrol  mercedes_benz                no
# 8                       12   petrol           opel                no
# ...                    ...      ...            ...               ...
# 49992                    9   diesel           opel                no
# 49993                    8   petrol        renault                no
# 49995                    3   petrol           opel                no
# 49998                    1   petrol            bmw                no
# 50000                   10   petrol      chevrolet                no
#
#       dateCreated  postalCode            lastSeen
# 1      2016-07-03       88045 2016-03-26 13:17:00
# 3      2016-03-19       34537 2016-07-04 04:44:00
# 5      2016-02-04       26826 2016-02-04 12:51:00
# 7      2016-03-24       13353 2016-03-27 12:45:00
# 8      2016-03-28       28307 2016-06-04 18:19:00
# ...           ...         ...                 ...
# 49992  2016-03-14       99310 2016-03-31 00:45:00
# 49993  2016-03-14       33659 2016-03-22 04:47:00
# 49995  2016-03-23       27305 2016-04-04 01:47:00
# 49998  2016-03-14       86956 2016-03-25 06:17:00
# 50000  2016-03-22        7973 2016-05-04 21:15:00
#
# [35348 rows x 19 columns]

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35348 entries, 1 to 50000
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          35348 non-null  datetime64[ns]
#  1   name                 35348 non-null  object
#  2   seller               35348 non-null  object
#  3   offerType            35348 non-null  object
#  4   price                35348 non-null  float64
#  5   abtest               35348 non-null  object
#  6   vehicleType          35348 non-null  object
#  7   yearOfRegistration   35348 non-null  int64
#  8   gearbox              35348 non-null  object
#  9   powerPS              35348 non-null  int64
#  10  model                35348 non-null  object
#  11  kilometer            35348 non-null  int64
#  12  monthOfRegistration  35348 non-null  int64
#  13  fuelType             35348 non-null  object
#  14  brand                35348 non-null  object
#  15  notRepairedDamage    35348 non-null  object
#  16  dateCreated          35348 non-null  datetime64[ns]
#  17  postalCode           35348 non-null  int64
#  18  lastSeen             35348 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(1), int64(5), object(10)
# memory usage: 5.4+ MB

# %%
dataframe.isna().sum()
# Out:
# dateCrawled            0
# name                   0
# seller                 0
# offerType              0
# price                  0
# abtest                 0
# vehicleType            0
# yearOfRegistration     0
# gearbox                0
# powerPS                0
# model                  0
# kilometer              0
# monthOfRegistration    0
# fuelType               0
# brand                  0
# notRepairedDamage      0
# dateCreated            0
# postalCode             0
# lastSeen               0
# dtype: int64

# %%
dataframe.describe()
# Out:
#               price  yearOfRegistration       powerPS      kilometer  \
# count  35348.000000        35348.000000  35348.000000   35348.000000
# mean       7.801996         2003.403502    114.790653  129262.193052
# std        1.513854           33.939824    202.245335   35893.868823
# min        0.000000         1910.000000      0.000000    5000.000000
# 25%        7.170888         1999.000000     75.000000  125000.000000
# 50%        8.006701         2003.000000    107.000000  150000.000000
# 75%        8.779711         2007.000000    143.000000  150000.000000
# max        9.695910         7500.000000  19312.000000  150000.000000
#
#        monthOfRegistration    postalCode
# count         35348.000000  35348.000000
# mean              6.072989  50975.709432
# std               3.544398  25729.256193
# min               0.000000   1067.000000
# 25%               3.000000  30855.000000
# 50%               6.000000  49759.500000
# 75%               9.000000  71697.250000
# max              12.000000  99998.000000

# %%
dataframe.to_csv('./data/final_result.csv')
